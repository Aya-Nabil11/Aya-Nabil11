# %% [markdown]
# <a href="https://colab.research.google.com/github/Aya-Nabil11/Aya-Nabil11/blob/main/goThroughTheBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hi')
# Out:
# Hi

# %%
x=5
print(x)
